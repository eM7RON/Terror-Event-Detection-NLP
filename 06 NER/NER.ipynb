# %% [markdown]
# This notebook will perform NER by using StanfordCoreNLP Server
#
# You will need the Python environment in the below cell.
#
# You will need Java 8 (64 bit) available here:
#
# https://www.java.com/en/download/manual.jsp
#
# Java may need to be added to your path
#
# You will need StanfordCoreNLP available here:
#
# https://stanfordnlp.github.io/CoreNLP/
#
# Then follow the instructions further down to start a server and run the notebook

# %%
print(__import__('sys').version)
# !conda list -n NLP37
# Out:
# 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]
# # packages in environment at C:\Anaconda3\envs\NLP37:
# #
# # Name                    Version                   Build  Channel
# _pytorch_select           1.1.0                       cpu
# altair                    3.1.0                    py37_0    conda-forge
# asn1crypto                0.24.0                   py37_0
# atomicwrites              1.3.0                    py37_1
# attrs                     19.1.0                   py37_1
# backcall                  0.1.0                    py37_0
# beautifulsoup4            4.7.1                    pypi_0    pypi
# blas                      1.0                         mkl
# boto                      2.49.0                   py37_0    anaconda
# boto3                     1.9.162                    py_0    anaconda
# botocore                  1.12.163                   py_0    anaconda
# branca                    0.3.1                      py_0    conda-forge
# bs4                       0.0.1                    pypi_0    pypi
# bz2file                   0.98                     py37_1    anaconda
# ca-certificates           2019.6.16            hecc5488_0    conda-forge
# cartopy                   0.17.0          py37hfff79a3_1006    conda-forge
# certifi                   2019.6.16                py37_1    conda-forge
# cffi                      1.12.3           py37h7a1dbc1_0
# chardet                   3.0.4                    pypi_0    pypi
# colorama                  0.4.1                    py37_0
# corenlp-xml-reader        0.1.3                    pypi_0    pypi
# corenlpy                  0.0.6                    pypi_0    pypi
# country-list              0.1.3                    pypi_0    pypi
# cryptography              2.7              py37h7a1dbc1_0
# cudatoolkit               10.0.130                      0
# cycler                    0.10.0                   py37_0
# cymem                     1.31.2           py37he980bc4_0
# cytoolz                   0.9.0.1          py37hfa6e2cd_1
# decorator                 4.4.0                    py37_1
# dill                      0.2.9                    py37_0
# docutils                  0.14                     py37_0    anaconda
# en-core-web-lg            2.0.0                    pypi_0    pypi
# en-core-web-md            2.0.0                    pypi_0    pypi
# en-core-web-sm            2.0.0                    pypi_0    pypi
# entrypoints               0.3                   py37_1000    conda-forge
# folium                    0.9.1                      py_0    conda-forge
# freetype                  2.9.1                ha9979f8_1
# funcy                     1.12                     pypi_0    pypi
# future                    0.17.1                   py37_0
# fuzzywuzzy                0.17.0                   pypi_0    pypi
# gensim                    3.4.0            py37hfa6e2cd_0    anaconda
# geographiclib             1.49                     pypi_0    pypi
# geopy                     1.20.0                   pypi_0    pypi
# geos                      3.7.2                habb2df7_1    conda-forge
# icc_rt                    2019.0.0             h0cc432a_1
# icu                       58.2                 ha66f8fd_1
# idna                      2.8                      pypi_0    pypi
# imbalanced-learn          0.5.0                    pypi_0    pypi
# importlib_metadata        0.17                     py37_1
# intel-openmp              2019.4                      245
# ipykernel                 5.1.1            py37h39e3cac_0
# ipython                   7.6.0            py37h39e3cac_0
# ipython_genutils          0.2.0                    py37_0
# jedi                      0.13.3                   py37_0
# jinja2                    2.10.1                   py37_0
# jmespath                  0.9.4                      py_0    anaconda
# joblib                    0.13.2                   py37_0
# jpeg                      9b                   hb83a4c4_2
# jsonschema                3.0.1                    py37_0    conda-forge
# jupyter_client            5.2.4                    py37_0
# jupyter_core              4.4.0                    py37_0
# kiwisolver                1.1.0            py37ha925a31_0
# libpng                    1.6.37               h2a8f88b_0
# libsodium                 1.0.16               h9d3ae62_0
# libtiff                   4.0.10               hb898794_2
# m2w64-gcc-libgfortran     5.3.0                         6
# m2w64-gcc-libs            5.3.0                         7
# m2w64-gcc-libs-core       5.3.0                         7
# m2w64-gmp                 6.1.0                         2
# m2w64-libwinpthread-git   5.0.0.4634.697f757               2
# markupsafe                1.1.1            py37he774522_0
# matplotlib                3.1.0            py37hc8f65d3_0
# mkl                       2019.4                      245
# mkl-service               2.0.2            py37he774522_0
# mkl_fft                   1.0.12           py37h14836fe_0
# mkl_random                1.0.2            py37h343c172_0
# more-itertools            7.0.0                    py37_0
# msgpack-numpy             0.4.4.2                  py37_0
# msgpack-python            0.5.6            py37he980bc4_1
# msys2-conda-epoch         20160418                      1
# murmurhash                0.28.0           py37he025d50_0
# networkx                  2.3                        py_0
# ninja                     1.9.0            py37h74a9793_0
# nltk                      3.4.1                    py37_0
# numexpr                   2.6.9            py37hdce8814_0
# numpy                     1.16.4           py37h19fb1c0_0
# numpy-base                1.16.4           py37hc3f5095_0
# olefile                   0.46                     py37_0
# openssl                   1.1.1c               hfa6e2cd_0    conda-forge
# owslib                    0.18.0                     py_0    conda-forge
# packaging                 19.0                     py37_0
# pandas                    0.24.2           py37ha925a31_0
# parso                     0.4.0                      py_0
# pickleshare               0.7.5                    py37_0
# pillow                    6.0.0            py37hdc69c19_0
# pip                       19.1.1                   py37_0
# plac                      0.9.6                    py37_0
# pluggy                    0.12.0                     py_0
# preshed                   1.0.1            py37he025d50_0
# proj4                     5.2.0             h6538335_1004    conda-forge
# prompt_toolkit            2.0.9                    py37_0
# protobuf                  3.8.0                    pypi_0    pypi
# py                        1.8.0                    py37_0
# pycorenlp                 0.3.0                    pypi_0    pypi
# pycountry                 19.7.15                  pypi_0    pypi
# pycparser                 2.19                     py37_0
# pyepsg                    0.4.0                      py_0    conda-forge
# pygments                  2.4.2                      py_0
# pykdtree                  1.3.1           py37h452e1ab_1002    conda-forge
# pyldavis                  2.1.2                    pypi_0    pypi
# pyopenssl                 19.0.0                   py37_0
# pyparsing                 2.4.0                      py_0
# pyproj                    1.9.6           py37hfa6e2cd_1002    conda-forge
# pyqt                      5.9.2            py37h6538335_2
# pyreadline                2.1                      py37_1
# pyrsistent                0.15.3           py37hfa6e2cd_0    conda-forge
# pyshp                     2.1.0                      py_0    conda-forge
# pysocks                   1.7.0                    py37_0
# pytest                    5.0.1                    py37_0
# python                    3.7.1                h8c8aaf0_6
# python-dateutil           2.8.0                    py37_0
# python-igraph             0.7.1.post6              pypi_0    pypi
# python-levenshtein        0.12.0          py37hfa6e2cd_1001    conda-forge
# python-louvain            0.13                       py_0
# pytorch                   1.1.0           py3.7_cuda100_cudnn7_1    pytorch
# pytz                      2019.1                     py_0
# pyzmq                     18.0.0           py37ha925a31_0
# qt                        5.9.7            vc14h73c81de_0
# regex                     2018.07.11       py37hfa6e2cd_0
# requests                  2.22.0                   py37_0
# s3transfer                0.2.0                    py37_0    anaconda
# scikit-learn              0.21.2           py37h6288b17_0
# scipy                     1.2.1            py37h29ff71c_0    anaconda
# selenium                  3.141.0          py37he774522_0
# setuptools                41.0.1                   py37_0
# shapely                   1.6.4           py37ha35856d_1006    conda-forge
# sip                       4.19.8           py37h6538335_0
# six                       1.12.0                   py37_0
# smart_open                1.8.4                      py_0    anaconda
# sner                      0.2.12                   pypi_0    pypi
# soupsieve                 1.9.2                    pypi_0    pypi
# spacy                     2.0.12           py37h8300f20_0
# sqlite                    3.28.0               he774522_0
# stanfordnlp               0.2.0                    pypi_0    pypi
# termcolor                 1.1.0                    py37_1
# thinc                     6.10.3           py37h8300f20_0
# tk                        8.6.8                hfa6e2cd_0
# toolz                     0.9.0                    py37_0
# torchvision               0.3.0              py37_cu100_1    pytorch
# tornado                   6.0.2            py37he774522_0
# tqdm                      4.32.2                   pypi_0    pypi
# traitlets                 4.3.2                    py37_0
# ujson                     1.35             py37hfa6e2cd_0
# urllib3                   1.25.3                   pypi_0    pypi
# vc                        14.1                 h0510ff6_4
# vincent                   0.4.4                      py_1    conda-forge
# vs2015_runtime            14.15.26706          h3a45250_4
# wcwidth                   0.1.7                    py37_0
# wheel                     0.33.4                   py37_0
# win_inet_pton             1.1.0                    py37_0
# wincertstore              0.2                      py37_0
# word2vec                  0.9.4            py37h452e1ab_0
# wordcloud                 1.5.0           py37hfa6e2cd_1000    conda-forge
# wrapt                     1.10.11          py37hfa6e2cd_2
# xlrd                      1.2.0                    py37_0
# xz                        5.2.4                h2fa13f4_4
# zeromq                    4.3.1                h33f27b4_3
# zipp                      0.5.1                      py_0
# zlib                      1.2.11               h62dcd97_3
# zstd                      1.3.7                h508b16e_0

# %%
# %pylab

from pycorenlp import StanfordCoreNLP
from datetime import datetime as dt
from tqdm import tqdm
from toolz import compose, curry, concat
from unicodedata import normalize
from string import punctuation

import datetime, os, re, string

try:
    import cPickle as pickle
except:
    import pickle
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Open a shell in your Stanford core download folder i.e.:
#
# cd C:\StanfordNLP\stanford-corenlp-full-2018-10-05

# %% [markdown]
# Then run the following command to start a server:
#
# java -mx12g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -maxCharLength 100000000000 -timeout 10000000000 -tokenize.options untokenizable=allDelete
#
# "-mx12g" designates the RAM you are allocating to the server (i.e. 12 GB) so makes sure you have it available
#
#
# Make sure the maxCharLength is equal to or larger than the MAX_CHARACTER_LENGTH variable in one of the below cells.
#
# To shut down the server at any time hold CTRL and press C when in the shell screen.
#
# The basic approach to this code is to exploit the fact that StanfordCoreNLPServer is faster when run on server, when only required annotators are used, when only required classese are loaded and when working on fewer larger strings rather than many smaller strings. With this in mind, we split the corpus into batches of roughly equal character length, add the date and article id information to the strings and then join each article together to create a single large string per batch. This leaves us with fewer larger strings and allows us to recapture the date and id information by searching in the tokens which are output by StanfordCoreNLP.

# %%
###########################################################################
#   These are the three main classifiers that perform NER. One may be     #
#   selected and used for the server. Testing shows CLF4 gives the best   #
#   results.                                                              #
###########################################################################

CLF3 = r'edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz'
CLF4 = r'edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz'
CLF7 = r'edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz'

# %%
def load_pickle(filename):
    print('Loading file...')
    with open(os.path.normpath(filename), 'rb') as open_file:
        return pickle.load(open_file)

def save_pickle(filename, data):
    print('saving...')
    with open(os.path.normpath(filename), 'wb') as open_file:
        pickle.dump(data, open_file)
        
def directory_explorer(extension, directory):
    '''
    A generator to find filenames with a given extension within a given 
    directory
    '''
    ext_upper, ext_lower = extension.lower(), extension.upper()
    for filename in os.listdir(os.path.normpath(directory)):
        if filename.endswith(ext_upper) \
        or filename.endswith(ext_lower):
            yield '%s/%s' % (directory, filename)

# %%
def unpack_dictionary(dic):
    '''
    Unpack dictionary data structure into a list for easier batch processing
    '''
    print('Unpacking data...')
    output = []
    for date in dic:
        for doc in dic[date]:
            copy = {
                    'id': doc['id'],
                    'content': doc['content'],
                    'datetime':date,
                    }
            
            output.append(copy)
    return output

# %%
def divide_into_batches(max_len, lis):
    '''
    Divides the corpus documents into batches
    '''
    output = []
    batch = []
    batch_len = 0
    for doc in lis:
        doc_len = len(doc['content'])
        if  (batch_len + doc_len) < max_len:
            batch.append(doc)
            batch_len += doc_len
        else:
            output.append(batch)
            batch = [doc]
            batch_len = doc_len
    if len(batch) > 0:
        output.append(batch)
    return output

# %%
def aggregate_articles(lis):
    '''
    Collects multiple articles into a single list
    '''
    print('Building input for NER...')
    output = []
    for doc in tqdm(lis):
           output.extend(['HEREISTHEDATE',
                          doc['datetime'].strftime('%d-%b-%Y'),
                          'HEREISTHEID', 
                          str(doc['id']),
                          doc['content'],
                          'ENDOFDOC.'])
    return output

# %%
def directory_explorer(extension, directory):
    '''
    A generator to find filenames with a given extension within a given 
    directory
    '''
    ext_upper, ext_lower = extension.lower(), extension.upper()
    for filename in os.listdir(os.path.normpath(directory)):
        if filename.endswith(ext_upper) \
        or filename.endswith(ext_lower):
            yield '%s/%s' % (directory, filename)

# %%
def unpack_ner_output(ner_output):
    '''
    Unpacks NER output
    
    Input:
        StanfordCoreNLP output
        
    Output:
        a list of dictionaries where each dictionary represents a document with
        a datetime object, unique id and a list of lists where each nested list is
        a sentence containing the entities that occurred in that sentence in the document.
        Entities are represented as objects
    '''

    print('Unpacking NER output...')
    output = {'n_articles': 0}
    doc = {}
    sentencewise_ents = []
    date_flag = None
    id_flag = None
    stop_flag = False
    
#     if len(custom_entities) > 0:
#         search_for_custom_entities = True
#     else:
#         False
    if type(ner_output) == str:
        raise Exception('StanfordCoreNLPSever as encountered an error: %s' % ner_output)
        
    for sentence in tqdm(ner_output['sentences']):
            
        ent_flag = False
        ents = []
            
        for token in sentence['tokens']:

            if token['word'] == 'ENDOFDOC':
                stop_flag = True

            ######################################################################
            #                           Collect Date                             #
            ######################################################################

            if 'HEREISTHEDATE' in token['word']:
                date_flag = True
                continue
            if date_flag:
                date = dt.strptime(token['word'], '%d-%b-%Y')
                if date not in output:
                    output[date] = {}
                date_flag = False
                continue

            ######################################################################
            #                           Collect ID                               #
            ######################################################################

            if 'HEREISTHEID' in token['word']:
                id_flag = True
                continue
            if id_flag:
                doc['id'] = int(token['word'])
                id_flag = False
                continue

#             ######################################################################
#             #                        Collect Entities                            #
#             ######################################################################
            
#             if search_for_custom_entities:
#                 if token['word'] in custom_entities:
#                     ents.append({'word': token['word'], 'tag': token['ner']})
#                     ent_flag = False

            if token['ner'] != 'O': # Entity
                if ent_flag:
                    # Same entity class
                    if token['ner'] == entity['tag']:
                        entity['word'] = '%s %s' % (entity['word'], token['word'])
                    # Different entity classes
                    else:
                        ents.append(entity)
                        entity = {'word': token['word'], 'tag': token['ner']}
                else:
                    entity = {'word': token['word'], 'tag': token['ner']}
                    ent_flag = True # Collect following entities of same class

            elif token['ner'] == 'O': # Non-Entity
                if ent_flag:
                    ents.append(entity) # Capture previous entity
                    entity = {'word': None, 'tag': None}
                ent_flag = False
            
        if len(ents) > 0:
            sentencewise_ents.append(ents)
                
        if stop_flag:
            if ent_flag:
                ents.append(entity)
                entity = {'word': None, 'tag': None}
                ent_flag = False
            doc['sentences'] = sentencewise_ents
            output[date][doc['id']] = doc
            output['n_articles'] += 1
            sentencewise_ents = []
            doc = {}
            stop_flag = False

    return output

# %%
def extract_persons(ner_output):
    print('Extracting persons...')
    output = []
    person = []
    for sentence in ner_output['sentences']:
        for token in sentence['tokens']:
            if token['ner'] != 'PERSON':
                if len(person) > 1:
                    output.append(' '.join(person))
                    person = []
                elif person:
                    person = []
            elif token['ner'] == 'PERSON':
                person.append(token['word'])
    return output

# %%
def directory_explorer(extension, directory):
    '''
    A generator to find filenames with a given extension within a given 
    directory
    '''
    ext_upper, ext_lower = extension.lower(), extension.upper()
    for filename in os.listdir(os.path.normpath(directory)):
        if filename.endswith(ext_upper) \
        or filename.endswith(ext_lower):
            yield '%s/%s' % (directory, filename)

# %%
class NER:
    '''
    A simple wrapper for StanfordCoreNLP mainly for simpler syntax
    '''
    def __init__(self, **kwargs):
        port = kwargs.get('port', '9000')
        self.clf = kwargs.get('clf', __import__('pycorenlp').StanfordCoreNLP('http://localhost:%s' % port))
        self.properties = kwargs.get(
            'properties', {
                           'annotators': 'tokenize, ssplit, pos, lemma, ner',
                           'ner.model': 'edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz',
                           'ner.useSUTime': 'false',
                           'ner.applyNumericClassifiers': 'false',
                           #'tokenizerFactory': 'edu/stanford/nlp.process/PTBLexer',
                           'tokenizer.options': "untokenizable=noneDelete",
                           'outputFormat': 'json',
                           #'maxCharLength': 1000000000,
#                            'timeout': 6000000,
                           })
        print('Initializing...')
        self.annotate('Initialization in progress...')
        print('Complete.')
        
    def annotate(self, text):
        print('Performing NER...')
        return self.clf.annotate(text, properties=self.properties)
    
#java -mx11g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 6000000 -maxCharLength 1000000000 -ner.model edu.stanford.nlp.models.ner.english.conll.4class.distsim.crf.ser.gz -ner.useSUTime false -ner.applyNumericClassifiers false -tokenizerFactory edu.stanford.nlp.process.PTBTokenizer -tokenizerOptions "untokenizable=noneDelete"

# %% [markdown]
# #### Main Ner pipe
#
# The following code was used to perform NER on the filtered corpus.

# %%
###########################################################################
#                              Constants                                  #
###########################################################################

TEMPORARY_FOLDER = r'temp'
INPUT_FILENAME = r'C:\Users\Simon\OneDrive - University of Exeter\__Project__\05 Filter Docs\temp\filtered.pkl'
PATH_TO_STANFORDNLP = r'C:\StanfordNLP\stanford-corenlp-full-2018-10-05'

MAX_CHARACTER_LENGTH = 1e7

# %% [markdown]
# You need a StanfordCoreNLP Server running to run this cell.

# %%
ner = NER()

##########################################################################
#                       For splitting pipe flow                          #
##########################################################################

left_fork = lambda f, x: (f(x), x)

right_fork = lambda f, x: (x, f(x))

right_deactivated_fork = lambda x: (x, y) 

unpack_tuple = lambda f, x: f(*x)

##########################################################################
#                         More auxillary functions                       #
##########################################################################

def loss_check(x, y):
    '''
    To Check all articles are recovered
    '''
    assert len(x) == y['n_articles']
    return y

i = 0

def create_savename(temp, x):
    '''
    To generate a single savename for a batch
    '''
    savename = '%s/batch %s.pkl' % (temp, i)
    i += 1
    #global i
    return savename

create_savenames = compose(
                           list,
                           curry(map)(lambda x: '%s/batch %s.pkl' % (TEMPORARY_FOLDER, x)),
                           range,
                           len,
                           )

save_batches = curry(unpack_tuple)(curry(map)(save_pickle))

concatonate_by_space = lambda x: ' '.join(x)

join = lambda x: ''.join(x)

save_batch = curry(unpack_tuple)(save_pickle) #lambda x: save_pickle(*x)

file_finder = curry(directory_explorer)('.pkl')
# Out:
# Initializing...
# Performing NER...
# Complete.

# %%
batch_creation_pipe = compose( 
                              list,
                              save_batches,
                              curry(left_fork)(create_savenames),
                              curry(divide_into_batches)(MAX_CHARACTER_LENGTH),
                              load_pickle,
                              )

core_pipe = compose(
                    unpack_ner_output,
                    ner.annotate,
                    join,
                    list,
                    concatonate_by_space, # ' '.join(x)
                    aggregate_articles,   # formats a batch into a list of strings 
                    )

inner_pipe = compose(
                     curry(unpack_tuple)(loss_check), # Check all docs are recovered
                     curry(right_fork)(core_pipe),
                     load_pickle,
                     )

outer_pipe = compose(
                     save_batch,
                     curry(right_fork)(inner_pipe),
                     )

ner_pipe = compose(
                   list,
                   curry(map)(outer_pipe),
                   list,
                   file_finder,
                   )

# %% [markdown]
# Running this cell will execute the NER process in two stages:
#
# 1) An initial partitioning of the input data is performed, each batch is saved in a temporary folder.
#
# 2) The NER pipe searches the temporary folder and performs NER on each batch and then overwrites it with
# found entities.

# %%
batch_creation_pipe(INPUT_FILENAME)
ner_pipe(TEMPORARY_FOLDER)
# Out:
# Loading file...
# saving...
# Loading file...
# Building input for NER...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<?, ?it/s]
# Performing NER...
# Unpacking NER output...
# 100%|█████████████████████████████████████████████████████████████████████████████| 319/319 [00:00<00:00, 79632.36it/s]
# saving...
# [None]

# %%
load_pickle(r'temp\batch 0.pkl')
# Out:
# Loading file...
# {'n_articles': 13,
#  datetime.datetime(2017, 1, 19, 0, 0): {20: {'id': 20,
#    'sentences': [[{'word': 'Pakistani', 'tag': 'NATIONALITY'}],
#     [{'word': 'Qamar Javed Bajwa', 'tag': 'PERSON'},
#      {'word': 'commander', 'tag': 'TITLE'},
#      {'word': 'Nawaz Sharif', 'tag': 'PERSON'},
#      {'word': 'prime minister', 'tag': 'TITLE'}],
#     [{'word': 'Sharif', 'tag': 'PERSON'}, {'word': 'general', 'tag': 'TITLE'}],
#     [{'word': 'General', 'tag': 'TITLE'},
#      {'word': 'Bajwa', 'tag': 'PERSON'},
#      {'word': 'Sharif', 'tag': 'PERSON'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Islamist', 'tag': 'IDEOLOGY'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'terrorism', 'tag': 'CRIMINAL_CHARGE'}],
#     [{'word': 'general', 'tag': 'TITLE'}],
#     [{'word': 'senior minister', 'tag': 'TITLE'},
#      {'word': 'terrorism', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'intelligence chief', 'tag': 'TITLE'},
#      {'word': 'Sharif', 'tag': 'PERSON'}],
#     [{'word': 'General', 'tag': 'TITLE'}, {'word': 'Bajwa', 'tag': 'PERSON'}],
#     [{'word': 'Sharif', 'tag': 'PERSON'},
#      {'word': 'General', 'tag': 'TITLE'},
#      {'word': 'Bajwa', 'tag': 'PERSON'},
#      {'word': 'Raheel Sharif', 'tag': 'PERSON'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Peshawar', 'tag': 'CITY'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Taliban', 'tag': 'IDEOLOGY'},
#      {'word': 'Isis', 'tag': 'ORGANIZATION'},
#      {'word': 'al-Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Mr Sharif', 'tag': 'PERSON'},
#      {'word': 'General', 'tag': 'TITLE'},
#      {'word': 'Sharif', 'tag': 'PERSON'}],
#     [{'word': 'Pakistani', 'tag': 'NATIONALITY'},
#      {'word': 'military chief', 'tag': 'TITLE'}],
#     [{'word': 'prime minister', 'tag': 'TITLE'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'general', 'tag': 'TITLE'}],
#     [{'word': 'second', 'tag': 'TITLE'},
#      {'word': 'assassinations', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'India', 'tag': 'COUNTRY'},
#      {'word': 'General', 'tag': 'TITLE'},
#      {'word': 'Bajwa', 'tag': 'PERSON'},
#      {'word': 'Kashmir', 'tag': 'LOCATION'}],
#     [{'word': 'guard', 'tag': 'TITLE'}],
#     [{'word': 'Inter-Services Intelligence', 'tag': 'ORGANIZATION'},
#      {'word': 'ISI', 'tag': 'ORGANIZATION'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   30: {'id': 30,
#    'sentences': [[{'word': 'Islamic', 'tag': 'IDEOLOGY'},
#      {'word': 'Iraqi', 'tag': 'NATIONALITY'},
#      {'word': 'suicide bomber', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Paris', 'tag': 'CITY'},
#      {'word': 'French', 'tag': 'NATIONALITY'}],
#     [{'word': 'Ammar Ramadan Mansour Mohamad al Sabaawi', 'tag': 'PERSON'}],
#     [{'word': 'Europe', 'tag': 'LOCATION'}],
#     [{'word': 'attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Stade', 'tag': 'CITY'},
#      {'word': 'de', 'tag': 'LOCATION'},
#      {'word': 'France', 'tag': 'COUNTRY'},
#      {'word': 'Bataclan', 'tag': 'MISC'}],
#     [{'word': 'Salah Abdeslam', 'tag': 'PERSON'},
#      {'word': 'Belgium', 'tag': 'COUNTRY'}],
#     [{'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Direction Generale de la Securite Exterieure',
#       'tag': 'ORGANIZATION'},
#      {'word': 'MI6', 'tag': 'ORGANIZATION'},
#      {'word': 'Sabaawi', 'tag': 'PERSON'}],
#     [{'word': 'Iraq', 'tag': 'COUNTRY'}],
#     [{'word': 'Mosul', 'tag': 'LOCATION'}],
#     [{'word': 'Isis', 'tag': 'ORGANIZATION'}],
#     [{'word': 'suicide attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Baghdad', 'tag': 'CITY'}],
#     [{'word': 'French', 'tag': 'NATIONALITY'},
#      {'word': 'Isis', 'tag': 'ORGANIZATION'},
#      {'word': 'France', 'tag': 'COUNTRY'}],
#     [{'word': 'Loic Garnier', 'tag': 'PERSON'},
#      {'word': 'French', 'tag': 'NATIONALITY'},
#      {'word': 'Iraq', 'tag': 'COUNTRY'},
#      {'word': 'Syria', 'tag': 'COUNTRY'}],
#     [{'word': 'Islamists', 'tag': 'MISC'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   41: {'id': 41,
#    'sentences': [[{'word': 'Tunisia', 'tag': 'COUNTRY'}],
#     [{'word': 'representative', 'tag': 'TITLE'},
#      {'word': 'Tui', 'tag': 'PERSON'},
#      {'word': 'Thomson', 'tag': 'PERSON'},
#      {'word': 'First Choice', 'tag': 'ORGANIZATION'},
#      {'word': 'Tunisian', 'tag': 'NATIONALITY'}],
#     [{'word': 'Venancio Lopez', 'tag': 'PERSON'},
#      {'word': 'Islamist', 'tag': 'IDEOLOGY'},
#      {'word': 'Bardo', 'tag': 'LOCATION'},
#      {'word': 'Tunis', 'tag': 'CITY'}],
#     [{'word': 'Seifeddine Rezgui', 'tag': 'PERSON'},
#      {'word': 'assault', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'Imperial Marhaba', 'tag': 'ORGANIZATION'},
#      {'word': 'Tui', 'tag': 'PERSON'},
#      {'word': 'assault', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'explosives', 'tag': 'CRIMINAL_CHARGE'}],
#     [{'word': 'Lopez', 'tag': 'PERSON'},
#      {'word': 'managing director', 'tag': 'TITLE'},
#      {'word': 'Tunisie Voyages', 'tag': 'ORGANIZATION'},
#      {'word': 'Tui', 'tag': 'LOCATION'},
#      {'word': 'British', 'tag': 'NATIONALITY'}],
#     [{'word': 'Britons', 'tag': 'MISC'}, {'word': 'general', 'tag': 'TITLE'}],
#     [{'word': 'Tunisotel', 'tag': 'PERSON'},
#      {'word': 'Riu', 'tag': 'LOCATION'},
#      {'word': 'Sousse', 'tag': 'LOCATION'},
#      {'word': 'Imperial Marhaba', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Rezgui', 'tag': 'PERSON'},
#      {'word': 'Imperial Marhaba', 'tag': 'ORGANIZATION'}],
#     [{'word': 'London', 'tag': 'CITY'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   53: {'id': 53,
#    'sentences': [[{'word': 'Jos Buttler', 'tag': 'PERSON'},
#      {'word': 'Eoin Morgan', 'tag': 'PERSON'},
#      {'word': 'revolutionary', 'tag': 'IDEOLOGY'},
#      {'word': 'England', 'tag': 'COUNTRY'},
#      {'word': 'second', 'tag': 'TITLE'},
#      {'word': 'India', 'tag': 'COUNTRY'},
#      {'word': 'captain', 'tag': 'TITLE'}],
#     [{'word': 'Morgan', 'tag': 'PERSON'},
#      {'word': 'England', 'tag': 'COUNTRY'}],
#     [{'word': 'Cuttack', 'tag': 'LOCATION'},
#      {'word': 'second', 'tag': 'TITLE'}],
#     [{'word': 'Barabati Stadium', 'tag': 'LOCATION'},
#      {'word': 'GMT', 'tag': 'MISC'}],
#     [{'word': 'second', 'tag': 'TITLE'}],
#     [{'word': 'England', 'tag': 'COUNTRY'},
#      {'word': 'ODI', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Adil Rashid', 'tag': 'PERSON'}],
#     [{'word': 'England', 'tag': 'COUNTRY'},
#      {'word': 'Pune', 'tag': 'CITY'},
#      {'word': 'Buttler', 'tag': 'PERSON'}],
#     [{'word': 'India', 'tag': 'COUNTRY'},
#      {'word': 'England', 'tag': 'COUNTRY'},
#      {'word': 'Virat Kohli', 'tag': 'PERSON'},
#      {'word': 'Jake Ball', 'tag': 'PERSON'}],
#     [{'word': 'KL Rahul', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Kohli', 'tag': 'PERSON'},
#      {'word': 'charter', 'tag': 'TITLE'},
#      {'word': 'Pune', 'tag': 'CITY'},
#      {'word': 'England', 'tag': 'COUNTRY'}],
#     [{'word': 'Indians', 'tag': 'MISC'}],
#     [{'word': 'England', 'tag': 'COUNTRY'},
#      {'word': 'Jason Roy', 'tag': 'PERSON'},
#      {'word': 'Alex Hales', 'tag': 'PERSON'},
#      {'word': 'Joe Root', 'tag': 'PERSON'},
#      {'word': 'Eoin Morgan', 'tag': 'PERSON'},
#      {'word': 'Ben Stokes', 'tag': 'PERSON'},
#      {'word': 'Jos Buttler', 'tag': 'PERSON'},
#      {'word': 'Moeen Ali', 'tag': 'PERSON'},
#      {'word': 'Chris Woakes', 'tag': 'PERSON'},
#      {'word': 'Adil Rashid', 'tag': 'PERSON'},
#      {'word': 'Liam Plunkett', 'tag': 'PERSON'},
#      {'word': 'David Willey', 'tag': 'PERSON'},
#      {'word': 'Jake Ball', 'tag': 'PERSON'}],
#     [{'word': 'India', 'tag': 'COUNTRY'},
#      {'word': 'Shikhar Dhawan', 'tag': 'PERSON'},
#      {'word': 'KL Rahul', 'tag': 'ORGANIZATION'},
#      {'word': 'Virat Kohli', 'tag': 'PERSON'},
#      {'word': 'Yuvraj Singh', 'tag': 'PERSON'},
#      {'word': 'Mahendra-Singh Dhoni', 'tag': 'PERSON'},
#      {'word': 'Kedar Jadhav', 'tag': 'PERSON'},
#      {'word': 'Hardik Pandya', 'tag': 'PERSON'},
#      {'word': 'Ravindra Jadeja', 'tag': 'PERSON'},
#      {'word': 'Ravichandran Ashwin', 'tag': 'PERSON'},
#      {'word': 'Jasprit Bumrah', 'tag': 'PERSON'},
#      {'word': 'Amit Mishra', 'tag': 'PERSON'},
#      {'word': 'Umesh Yadav', 'tag': 'PERSON'}],
#     [{'word': 'R Palliyaguruge', 'tag': 'PERSON'},
#      {'word': 'C Shamshuddin', 'tag': 'PERSON'},
#      {'word': 'Ind', 'tag': 'STATE_OR_PROVINCE'}],
#     [{'word': 'umpire', 'tag': 'TITLE'},
#      {'word': 'K Dharmasena', 'tag': 'PERSON'}],
#     [{'word': 'referee', 'tag': 'TITLE'}],
#     [{'word': 'Sky Sports', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Morgan', 'tag': 'ORGANIZATION'},
#      {'word': 'deputy', 'tag': 'TITLE'},
#      {'word': 'Buttler', 'tag': 'PERSON'}],
#     [{'word': 'IPL', 'tag': 'ORGANIZATION'},
#      {'word': 'Buttler', 'tag': 'PERSON'},
#      {'word': 'Mumbai Indians', 'tag': 'MISC'}],
#     [{'word': 'World Twenty20', 'tag': 'MISC'},
#      {'word': 'Calcutta', 'tag': 'CITY'},
#      {'word': 'Ashes-winning', 'tag': 'MISC'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   101: {'id': 101,
#    'sentences': [[{'word': 'Iraqi', 'tag': 'NATIONALITY'},
#      {'word': 'Mosul', 'tag': 'LOCATION'},
#      {'word': 'River', 'tag': 'TITLE'},
#      {'word': 'Tigris', 'tag': 'LOCATION'},
#      {'word': 'Islamic', 'tag': 'IDEOLOGY'}],
#     [{'word': 'Mosul', 'tag': 'LOCATION'},
#      {'word': 'Lieutenant-General', 'tag': 'TITLE'},
#      {'word': 'Talib Shaghati', 'tag': 'PERSON'},
#      {'word': 'US-trained', 'tag': 'COUNTRY'},
#      {'word': 'Golden Division', 'tag': 'MISC'}],
#     [{'word': 'Isis', 'tag': 'ORGANIZATION'},
#      {'word': 'Iraqi', 'tag': 'NATIONALITY'},
#      {'word': 'Prophet', 'tag': 'TITLE'},
#      {'word': 'Jonah', 'tag': 'PERSON'},
#      {'word': 'Grand Mosque', 'tag': 'MISC'}],
#     [{'word': 'Said Aya Saad', 'tag': 'PERSON'}],
#     [{'word': 'Neighbours', 'tag': 'PERSON'},
#      {'word': 'Isis', 'tag': 'ORGANIZATION'}],
#     [{'word': 'assault', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'Mosul', 'tag': 'LOCATION'}],
#     [{'word': 'British', 'tag': 'NATIONALITY'},
#      {'word': 'American', 'tag': 'NATIONALITY'},
#      {'word': 'Golden Division', 'tag': 'MISC'},
#      {'word': 'Isis', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Jonah', 'tag': 'LOCATION'},
#      {'word': 'Iraq', 'tag': 'COUNTRY'},
#      {'word': 'Anbar', 'tag': 'LOCATION'}],
#     [{'word': 'Hevidar Ahmed', 'tag': 'PERSON'},
#      {'word': 'reporter', 'tag': 'TITLE'},
#      {'word': 'Rudaw', 'tag': 'PERSON'},
#      {'word': 'Kurdish', 'tag': 'MISC'},
#      {'word': 'Iraq', 'tag': 'COUNTRY'},
#      {'word': 'journalist', 'tag': 'TITLE'},
#      {'word': 'prophet', 'tag': 'TITLE'},
#      {'word': 'Arabic', 'tag': 'MISC'},
#      {'word': 'Nabi Yunus', 'tag': 'PERSON'}],
#     [{'word': 'Assyrian', 'tag': 'MISC'},
#      {'word': 'Nineveh', 'tag': 'LOCATION'},
#      {'word': 'Isis', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Jonah', 'tag': 'PERSON'},
#      {'word': 'Old Testament', 'tag': 'IDEOLOGY'},
#      {'word': 'Nineveh', 'tag': 'LOCATION'},
#      {'word': 'Mosul', 'tag': 'LOCATION'}],
#     [{'word': 'Arab', 'tag': 'MISC'}],
#     [{'word': 'Jonah', 'tag': 'PERSON'}, {'word': 'Americans', 'tag': 'MISC'}],
#     [{'word': 'Rudaw', 'tag': 'MISC'}],
#     [{'word': 'assault', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'river', 'tag': 'TITLE'}],
#     [{'word': 'Great Mosque of al-Nuri', 'tag': 'LOCATION'},
#      {'word': 'leader', 'tag': 'TITLE'},
#      {'word': 'Isis', 'tag': 'ORGANIZATION'},
#      {'word': 'Abu Bakr al-Baghdadi', 'tag': 'PERSON'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   136: {'id': 136,
#    'sentences': [[{'word': 'Al Qaeda', 'tag': 'PERSON'},
#      {'word': 'suicide', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'bombing', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'West Africa', 'tag': 'LOCATION'},
#      {'word': 'Mali', 'tag': 'COUNTRY'}],
#     [{'word': 'attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Gao', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Al Mourabitoun', 'tag': 'PERSON'},
#      {'word': 'attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Facebook', 'tag': 'MISC'},
#      {'word': 'Mauritanian', 'tag': 'NATIONALITY'},
#      {'word': 'Al-Akhbar', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Mali', 'tag': 'COUNTRY'},
#      {'word': 'Al Qaeda', 'tag': 'PERSON'},
#      {'word': 'North', 'tag': 'MISC'},
#      {'word': 'African', 'tag': 'NATIONALITY'},
#      {'word': 'Al Qaeda', 'tag': 'PERSON'},
#      {'word': 'Islamic', 'tag': 'IDEOLOGY'},
#      {'word': 'Maghreb', 'tag': 'MISC'},
#      {'word': 'AQIM', 'tag': 'ORGANIZATION'}],
#     [{'word': 'French', 'tag': 'NATIONALITY'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Al Mourabitoun', 'tag': 'PERSON'},
#      {'word': 'Mokhtar Belmokhtar', 'tag': 'PERSON'},
#      {'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Mali', 'tag': 'COUNTRY'},
#      {'word': 'Africa', 'tag': 'LOCATION'}],
#     [{'word': 'Belmokhtar', 'tag': 'PERSON'}],
#     [{'word': 'United States', 'tag': 'COUNTRY'}],
#     [{'word': 'Francois Delattre', 'tag': 'PERSON'},
#      {'word': 'France', 'tag': 'COUNTRY'},
#      {'word': 'ambassador', 'tag': 'TITLE'},
#      {'word': 'United Nations', 'tag': 'ORGANIZATION'},
#      {'word': 'attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Mali', 'tag': 'COUNTRY'}],
#     [{'word': 'Mali', 'tag': 'COUNTRY'},
#      {'word': 'French', 'tag': 'NATIONALITY'},
#      {'word': 'Islamist', 'tag': 'IDEOLOGY'}],
#     [{'word': 'Tuareg', 'tag': 'MISC'}],
#     [{'word': 'Islamist', 'tag': 'IDEOLOGY'},
#      {'word': 'Tuareg', 'tag': 'MISC'},
#      {'word': 'Malian', 'tag': 'NATIONALITY'},
#      {'word': 'Mali', 'tag': 'COUNTRY'}],
#     [{'word': 'Mali', 'tag': 'COUNTRY'}, {'word': 'France', 'tag': 'COUNTRY'}],
#     [{'word': 'United Nations', 'tag': 'ORGANIZATION'}],
#     [{'word': 'French', 'tag': 'NATIONALITY'}],
#     [{'word': 'Algerian-brokered', 'tag': 'MISC'},
#      {'word': 'Coordination of Movements of Azawad', 'tag': 'ORGANIZATION'},
#      {'word': 'Tuareg-led', 'tag': 'MISC'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   141: {'id': 141,
#    'sentences': [[{'word': 'Defense Secretary', 'tag': 'TITLE'},
#      {'word': 'James Mattis', 'tag': 'PERSON'},
#      {'word': 'Pentagon', 'tag': 'ORGANIZATION'},
#      {'word': 'President', 'tag': 'TITLE'},
#      {'word': 'Donald Trump', 'tag': 'PERSON'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'Pentagon', 'tag': 'ORGANIZATION'},
#      {'word': 'Mattis', 'tag': 'PERSON'},
#      {'word': 'Joint Chiefs of Staff', 'tag': 'ORGANIZATION'},
#      {'word': 'Chairman Gen.', 'tag': 'TITLE'},
#      {'word': 'Joseph Dunford', 'tag': 'PERSON'},
#      {'word': 'President', 'tag': 'TITLE'}],
#     [{'word': 'Dunford', 'tag': 'PERSON'},
#      {'word': 'Gen.', 'tag': 'TITLE'},
#      {'word': 'Joseph Votel', 'tag': 'PERSON'},
#      {'word': 'US Central Command', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Defense Department', 'tag': 'ORGANIZATION'},
#      {'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'President', 'tag': 'TITLE'}],
#     [{'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'Russia', 'tag': 'COUNTRY'}],
#     [{'word': 'Mattis', 'tag': 'PERSON'},
#      {'word': 'Pentagon', 'tag': 'ORGANIZATION'},
#      {'word': 'leader', 'tag': 'TITLE'},
#      {'word': 'White House', 'tag': 'LOCATION'}],
#     [{'word': 'White House', 'tag': 'LOCATION'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'Barack Obama', 'tag': 'PERSON'},
#      {'word': 'White House', 'tag': 'LOCATION'}],
#     [{'word': 'President', 'tag': 'TITLE'}],
#     [{'word': 'Raqqa', 'tag': 'LOCATION'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'Syria', 'tag': 'COUNTRY'},
#      {'word': 'Kurdish', 'tag': 'MISC'}],
#     [{'word': 'Obama', 'tag': 'PERSON'}, {'word': 'Turkey', 'tag': 'COUNTRY'}],
#     [{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Turkey', 'tag': 'COUNTRY'},
#      {'word': 'Turks', 'tag': 'MISC'},
#      {'word': 'US', 'tag': 'COUNTRY'}],
#     [{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Syria', 'tag': 'COUNTRY'},
#      {'word': 'Raqqa', 'tag': 'LOCATION'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'}],
#     [{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Kurdish', 'tag': 'MISC'},
#      {'word': 'Raqqa', 'tag': 'PERSON'}],
#     [{'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'Syria', 'tag': 'COUNTRY'},
#      {'word': 'Bashar al-Assad', 'tag': 'PERSON'}],
#     [{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Russian', 'tag': 'NATIONALITY'},
#      {'word': 'Syria', 'tag': 'COUNTRY'}],
#     [{'word': 'Iraq', 'tag': 'COUNTRY'},
#      {'word': 'Syria', 'tag': 'COUNTRY'},
#      {'word': 'Trump', 'tag': 'LOCATION'}],
#     [{'word': 'Obama', 'tag': 'PERSON'}, {'word': 'US', 'tag': 'COUNTRY'}],
#     [{'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'Libya', 'tag': 'LOCATION'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   154: {'id': 154,
#    'sentences': [[{'word': 'NATO', 'tag': 'ORGANIZATION'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'},
#      {'word': 'spokesperson', 'tag': 'TITLE'},
#      {'word': 'Oana Lungescu', 'tag': 'PERSON'},
#      {'word': 'CNN', 'tag': 'ORGANIZATION'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Lungescu', 'tag': 'PERSON'}],
#     [{'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'NATO', 'tag': 'ORGANIZATION'}],
#     [{'word': 'President-elect', 'tag': 'TITLE'},
#      {'word': 'Donald Trump', 'tag': 'PERSON'},
#      {'word': 'British', 'tag': 'NATIONALITY'},
#      {'word': 'German', 'tag': 'NATIONALITY'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'},
#      {'word': 'Trump', 'tag': 'PERSON'}],
#     [{'word': 'Davos Forum', 'tag': 'ORGANIZATION'},
#      {'word': 'Switzerland', 'tag': 'COUNTRY'},
#      {'word': 'NATO', 'tag': 'ORGANIZATION'},
#      {'word': 'Secretary General', 'tag': 'TITLE'}],
#     [{'word': 'assault', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'NATO', 'tag': 'ORGANIZATION'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Article Five', 'tag': 'ORGANIZATION'},
#      {'word': 'attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Stoltenberg', 'tag': 'PERSON'}],
#     [{'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'},
#      {'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Russia', 'tag': 'COUNTRY'},
#      {'word': 'NATO', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Stoltenberg', 'tag': 'PERSON'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Russia', 'tag': 'COUNTRY'},
#      {'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'US', 'tag': 'COUNTRY'}],
#     [{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Russia', 'tag': 'COUNTRY'},
#      {'word': 'Europe', 'tag': 'LOCATION'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'},
#      {'word': 'Belgium', 'tag': 'COUNTRY'},
#      {'word': 'secretary general', 'tag': 'TITLE'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Davos', 'tag': 'LOCATION'},
#      {'word': 'Stoltenberg', 'tag': 'PERSON'},
#      {'word': 'NATO', 'tag': 'ORGANIZATION'},
#      {'word': 'terrorism', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'}],
#     [{'word': 'NATO', 'tag': 'ORGANIZATION'},
#      {'word': 'Stoltenberg', 'tag': 'PERSON'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   187: {'id': 187,
#    'sentences': [[{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Osama bin Laden', 'tag': 'ORGANIZATION'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'leader', 'tag': 'TITLE'}],
#     [{'word': 'Laden', 'tag': 'MISC'}, {'word': 'US', 'tag': 'COUNTRY'}],
#     [{'word': 'Laden', 'tag': 'ORGANIZATION'},
#      {'word': 'Abbottabad', 'tag': 'LOCATION'},
#      {'word': 'US Navy SEALs', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Obama', 'tag': 'PERSON'}, {'word': 'Trump', 'tag': 'LOCATION'}],
#     [{'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'US Navy SEALs', 'tag': 'ORGANIZATION'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'leader', 'tag': 'TITLE'},
#      {'word': 'Uthman', 'tag': 'PERSON'},
#      {'word': 'Muhammad', 'tag': 'PERSON'}],
#     [{'word': 'Uthman', 'tag': 'PERSON'},
#      {'word': 'Muhammad', 'tag': 'PERSON'},
#      {'word': 'Iran', 'tag': 'COUNTRY'},
#      {'word': 'Iranian', 'tag': 'NATIONALITY'}],
#     [{'word': 'Laden', 'tag': 'PERSON'},
#      {'word': 'Pakistani', 'tag': 'NATIONALITY'},
#      {'word': 'Peshawar', 'tag': 'CITY'}],
#     [{'word': 'Laden', 'tag': 'PERSON'},
#      {'word': 'Iranians', 'tag': 'MISC'},
#      {'word': 'Iran', 'tag': 'COUNTRY'}],
#     [{'word': 'Laden', 'tag': 'MISC'}],
#     [{'word': 'Laden', 'tag': 'PERSON'}, {'word': 'Hamza', 'tag': 'PERSON'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Hamza', 'tag': 'PERSON'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'},
#      {'word': 'Abbottabad', 'tag': 'LOCATION'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Laden', 'tag': 'ORGANIZATION'},
#      {'word': 'Hamza', 'tag': 'PERSON'},
#      {'word': 'Karachi', 'tag': 'CITY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Hamza', 'tag': 'PERSON'},
#      {'word': 'CIA', 'tag': 'ORGANIZATION'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'Laden', 'tag': 'ORGANIZATION'},
#      {'word': 'Abbottabad', 'tag': 'LOCATION'},
#      {'word': 'Hamza', 'tag': 'PERSON'}],
#     [{'word': 'Hamza', 'tag': 'PERSON'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'US State Department', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Laden', 'tag': 'ORGANIZATION'},
#      {'word': 'Khadija', 'tag': 'PERSON'}],
#     [{'word': 'Khadija', 'tag': 'PERSON'},
#      {'word': 'Afghanistan-Pakistan', 'tag': 'MISC'},
#      {'word': 'malaria', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'typhoid', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Khadija', 'tag': 'PERSON'}],
#     [{'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'leader', 'tag': 'TITLE'}],
#     [{'word': 'Abbottabad', 'tag': 'LOCATION'},
#      {'word': 'Internet', 'tag': 'MISC'},
#      {'word': 'Laden', 'tag': 'PERSON'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Nigeria', 'tag': 'COUNTRY'},
#      {'word': 'North Africa', 'tag': 'LOCATION'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Yemen', 'tag': 'COUNTRY'}],
#     [{'word': 'Laden', 'tag': 'ORGANIZATION'},
#      {'word': 'courier', 'tag': 'TITLE'},
#      {'word': 'Internet', 'tag': 'MISC'},
#      {'word': 'Abbottabad', 'tag': 'LOCATION'}],
#     [{'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'North', 'tag': 'MISC'},
#      {'word': 'African', 'tag': 'NATIONALITY'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Islamic', 'tag': 'IDEOLOGY'},
#      {'word': 'Maghreb', 'tag': 'MISC'},
#      {'word': 'AQIM', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'Iraqi', 'tag': 'NATIONALITY'},
#      {'word': 'Afghan', 'tag': 'NATIONALITY'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'AQIM', 'tag': 'ORGANIZATION'}],
#     [{'word': 'AQIM', 'tag': 'ORGANIZATION'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'leader', 'tag': 'TITLE'}],
#     [{'word': 'French', 'tag': 'NATIONALITY'},
#      {'word': 'AQIM', 'tag': 'ORGANIZATION'}],
#     [{'word': 'AQIM', 'tag': 'ORGANIZATION'}],
#     [{'word': 'leader', 'tag': 'TITLE'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Yemen', 'tag': 'COUNTRY'},
#      {'word': 'Laden', 'tag': 'PERSON'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'Laden', 'tag': 'PERSON'}],
#     [{'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'Yemen', 'tag': 'COUNTRY'},
#      {'word': 'Arab', 'tag': 'MISC'},
#      {'word': 'Islamic', 'tag': 'IDEOLOGY'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'Islamic', 'tag': 'IDEOLOGY'},
#      {'word': 'Iraq', 'tag': 'COUNTRY'},
#      {'word': 'Syria', 'tag': 'COUNTRY'}],
#     [{'word': 'Nigeria', 'tag': 'COUNTRY'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Boko Haram', 'tag': 'PERSON'},
#      {'word': 'kidnapping', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'Nigerian', 'tag': 'NATIONALITY'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'Shia', 'tag': 'RELIGION'},
#      {'word': 'Iran', 'tag': 'COUNTRY'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'leader', 'tag': 'TITLE'},
#      {'word': 'Iranians', 'tag': 'MISC'},
#      {'word': 'Iran', 'tag': 'COUNTRY'},
#      {'word': 'fall', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Taliban', 'tag': 'IDEOLOGY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'},
#      {'word': 'Laden', 'tag': 'MISC'},
#      {'word': 'Shia', 'tag': 'RELIGION'},
#      {'word': 'Islam', 'tag': 'RELIGION'}],
#     [{'word': 'Laden', 'tag': 'PERSON'}],
#     [{'word': 'murder', 'tag': 'CRIMINAL_CHARGE'},
#      {'word': 'BBC', 'tag': 'ORGANIZATION'},
#      {'word': 'photographer', 'tag': 'TITLE'},
#      {'word': 'Saudi Arabia', 'tag': 'COUNTRY'},
#      {'word': 'Simon Cumbers', 'tag': 'PERSON'},
#      {'word': 'terrorist attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Saudi', 'tag': 'NATIONALITY'},
#      {'word': 'Riyadh', 'tag': 'CITY'},
#      {'word': 'attack', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'BBC', 'tag': 'ORGANIZATION'},
#      {'word': 'correspondent', 'tag': 'TITLE'},
#      {'word': 'Frank Gardner', 'tag': 'PERSON'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'Laden', 'tag': 'ORGANIZATION'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Laden', 'tag': 'PERSON'},
#      {'word': 'Abbottabad', 'tag': 'LOCATION'}],
#     [{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'leader', 'tag': 'TITLE'}],
#     [{'word': 'Laden', 'tag': 'MISC'}],
#     [{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Laden', 'tag': 'PERSON'},
#      {'word': 'editor', 'tag': 'TITLE'}],
#     [{'word': 'courier', 'tag': 'TITLE'}],
#     [{'word': 'Abbottabad', 'tag': 'LOCATION'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'}, {'word': 'Laden', 'tag': 'MISC'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   197: {'id': 197,
#    'sentences': [[{'word': 'Office of the Director of National Intelligence',
#       'tag': 'ORGANIZATION'},
#      {'word': 'Osama bin Laden', 'tag': 'LOCATION'},
#      {'word': 'US', 'tag': 'COUNTRY'}],
#     [{'word': 'Laden', 'tag': 'ORGANIZATION'},
#      {'word': 'CNN', 'tag': 'ORGANIZATION'},
#      {'word': 'analyst', 'tag': 'TITLE'},
#      {'word': 'Peter Bergen', 'tag': 'PERSON'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'Muslims', 'tag': 'MISC'}],
#     [{'word': 'host', 'tag': 'TITLE'}],
#     [{'word': 'administrator', 'tag': 'TITLE'}],
#     [{'word': 'al Qaeda', 'tag': 'IDEOLOGY'}],
#     [{'word': 'general', 'tag': 'TITLE'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   198: {'id': 198,
#    'sentences': [[{'word': 'American', 'tag': 'NATIONALITY'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Taliban', 'tag': 'ORGANIZATION'},
#      {'word': 'leader', 'tag': 'TITLE'},
#      {'word': 'Mullah Akhtar Mansour', 'tag': 'PERSON'}],
#     [{'word': 'CIA', 'tag': 'ORGANIZATION'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Iraq', 'tag': 'COUNTRY'},
#      {'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'President', 'tag': 'TITLE'},
#      {'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'New', 'tag': 'LOCATION'},
#      {'word': 'America', 'tag': 'COUNTRY'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'CIA', 'tag': 'ORGANIZATION'},
#      {'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'New', 'tag': 'LOCATION'},
#      {'word': 'America', 'tag': 'COUNTRY'}],
#     [{'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Yemen', 'tag': 'COUNTRY'},
#      {'word': 'Somalia', 'tag': 'COUNTRY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Donald Trump', 'tag': 'PERSON'}],
#     [{'word': 'commander', 'tag': 'TITLE'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'al-Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'},
#      {'word': 'American', 'tag': 'NATIONALITY'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Pakistanis', 'tag': 'MISC'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'United States', 'tag': 'COUNTRY'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'Trump', 'tag': 'ORGANIZATION'},
#      {'word': 'general', 'tag': 'TITLE'}],
#     [{'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'President', 'tag': 'TITLE'},
#      {'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Mike Pompeo', 'tag': 'PERSON'},
#      {'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'Director', 'tag': 'TITLE'},
#      {'word': 'CIA', 'tag': 'ORGANIZATION'},
#      {'word': 'president', 'tag': 'TITLE'},
#      {'word': 'Americans', 'tag': 'MISC'}],
#     [{'word': 'General', 'tag': 'TITLE'},
#      {'word': 'James Mattis', 'tag': 'PERSON'},
#      {'word': 'Commander', 'tag': 'TITLE'},
#      {'word': 'Central Command', 'tag': 'ORGANIZATION'},
#      {'word': 'American', 'tag': 'NATIONALITY'},
#      {'word': 'Egypt', 'tag': 'COUNTRY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'Defense Secretary', 'tag': 'TITLE'},
#      {'word': 'Yemen', 'tag': 'COUNTRY'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Yemen', 'tag': 'COUNTRY'},
#      {'word': 'Mattis', 'tag': 'PERSON'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'Michael Flynn', 'tag': 'PERSON'},
#      {'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'National Security Adviser', 'tag': 'ORGANIZATION'},
#      {'word': 'Al Jazeera', 'tag': 'PERSON'}],
#     [{'word': 'Flynn', 'tag': 'PERSON'}, {'word': 'Trump', 'tag': 'PERSON'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'U.S.', 'tag': 'COUNTRY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Trump', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Pakistani', 'tag': 'NATIONALITY'},
#      {'word': 'Prime Minister', 'tag': 'TITLE'},
#      {'word': 'Nawaz Sharif', 'tag': 'PERSON'},
#      {'word': 'Pakistani', 'tag': 'NATIONALITY'},
#      {'word': 'Sharif', 'tag': 'PERSON'}],
#     [{'word': 'Senate Armed Services Committee', 'tag': 'ORGANIZATION'},
#      {'word': 'Mattis', 'tag': 'PERSON'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Osama bin Laden', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Obama', 'tag': 'PERSON'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'President', 'tag': 'TITLE'},
#      {'word': 'Obama', 'tag': 'PERSON'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Obama', 'tag': 'PERSON'}],
#     [{'word': 'Yemen', 'tag': 'COUNTRY'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'New', 'tag': 'LOCATION'},
#      {'word': 'America', 'tag': 'COUNTRY'}],
#     [{'word': 'Somalia', 'tag': 'COUNTRY'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'New', 'tag': 'LOCATION'},
#      {'word': 'America', 'tag': 'COUNTRY'}],
#     [{'word': 'Washington', 'tag': 'STATE_OR_PROVINCE'},
#      {'word': 'Iraq', 'tag': 'COUNTRY'},
#      {'word': 'Syria', 'tag': 'COUNTRY'}],
#     [{'word': 'Libya', 'tag': 'LOCATION'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'American', 'tag': 'NATIONALITY'}],
#     [{'word': 'Mullah Mansour', 'tag': 'PERSON'},
#      {'word': 'Balochistan', 'tag': 'LOCATION'},
#      {'word': 'American', 'tag': 'NATIONALITY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'},
#      {'word': 'United States', 'tag': 'COUNTRY'}],
#     [{'word': 'fall', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'fall', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'American', 'tag': 'NATIONALITY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Afghan-Pakistan', 'tag': 'MISC'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Taliban', 'tag': 'IDEOLOGY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'CIA', 'tag': 'ORGANIZATION'}],
#     [{'word': 'US Navy', 'tag': 'ORGANIZATION'},
#      {'word': 'Laden', 'tag': 'PERSON'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Taliban', 'tag': 'ORGANIZATION'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'}],
#     [{'word': 'General', 'tag': 'TITLE'},
#      {'word': 'John W. Nicholson', 'tag': 'PERSON'},
#      {'word': 'commander', 'tag': 'TITLE'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'al Qaeda', 'tag': 'IDEOLOGY'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'}],
#     [{'word': 'Congress', 'tag': 'ORGANIZATION'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Afghanistan', 'tag': 'COUNTRY'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'George W. Bush', 'tag': 'PERSON'},
#      {'word': 'Obama', 'tag': 'PERSON'}],
#     [{'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Pakistan', 'tag': 'COUNTRY'},
#      {'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'war', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]},
#   210: {'id': 210,
#    'sentences': [[{'word': 'imam', 'tag': 'TITLE'},
#      {'word': 'Muslim', 'tag': 'RELIGION'},
#      {'word': 'President-elect', 'tag': 'TITLE'},
#      {'word': 'Donald Trump', 'tag': 'PERSON'}],
#     [{'word': 'Imam', 'tag': 'TITLE'},
#      {'word': 'Mohamed Magid', 'tag': 'PERSON'},
#      {'word': 'All Dulles Area Muslim Society Center', 'tag': 'ORGANIZATION'},
#      {'word': 'ADAMS Center', 'tag': 'ORGANIZATION'},
#      {'word': 'Sterling', 'tag': 'CITY'},
#      {'word': 'Virginia', 'tag': 'STATE_OR_PROVINCE'},
#      {'word': 'Scripture', 'tag': 'MISC'},
#      {'word': 'National Prayer Service', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Washington', 'tag': 'STATE_OR_PROVINCE'},
#      {'word': 'National Cathedral', 'tag': 'LOCATION'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'Islam', 'tag': 'RELIGION'},
#      {'word': 'Muslim', 'tag': 'RELIGION'},
#      {'word': 'Islam', 'tag': 'RELIGION'}],
#     [{'word': 'Trump', 'tag': 'PERSON'},
#      {'word': 'Muslim', 'tag': 'RELIGION'}],
#     [{'word': 'Trump', 'tag': 'LOCATION'},
#      {'word': 'Muslim', 'tag': 'RELIGION'},
#      {'word': 'United States', 'tag': 'COUNTRY'}],
#     [{'word': 'Magid', 'tag': 'PERSON'},
#      {'word': 'Muslim', 'tag': 'RELIGION'},
#      {'word': 'Islamic', 'tag': 'IDEOLOGY'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'ADAMS Center', 'tag': 'ORGANIZATION'},
#      {'word': 'FBI', 'tag': 'ORGANIZATION'},
#      {'word': 'Muslim', 'tag': 'RELIGION'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]}},
#  datetime.datetime(2017, 1, 20, 0, 0): {223: {'id': 223,
#    'sentences': [[{'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'B-2', 'tag': 'MISC'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'Libya', 'tag': 'LOCATION'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'CNN', 'tag': 'ORGANIZATION'},
#      {'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Europe', 'tag': 'LOCATION'},
#      {'word': 'Defense Ash Carter', 'tag': 'ORGANIZATION'}],
#     [{'word': 'President', 'tag': 'TITLE'},
#      {'word': 'Barack Obama', 'tag': 'PERSON'}],
#     [{'word': 'Libya', 'tag': 'LOCATION'},
#      {'word': 'Africa', 'tag': 'LOCATION'},
#      {'word': 'Europe', 'tag': 'LOCATION'},
#      {'word': 'United States', 'tag': 'COUNTRY'},
#      {'word': 'Pentagon', 'tag': 'ORGANIZATION'},
#      {'word': 'spokesman', 'tag': 'TITLE'},
#      {'word': 'Peter Cook', 'tag': 'PERSON'}],
#     [{'word': 'US', 'tag': 'COUNTRY'}],
#     [{'word': 'Department of Defense', 'tag': 'ORGANIZATION'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'}],
#     [{'word': 'second', 'tag': 'TITLE'}],
#     [{'word': 'Pentagon', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Cook', 'tag': 'PERSON'}],
#     [{'word': 'US', 'tag': 'COUNTRY'}, {'word': 'Sirte', 'tag': 'LOCATION'}],
#     [{'word': 'Sirte', 'tag': 'LOCATION'},
#      {'word': 'Pentagon', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Cook', 'tag': 'PERSON'},
#      {'word': 'US Air Force B-2 Spirit', 'tag': 'ORGANIZATION'},
#      {'word': 'Whiteman Air Force Base', 'tag': 'ORGANIZATION'},
#      {'word': 'Missouri', 'tag': 'STATE_OR_PROVINCE'}],
#     [{'word': 'attack', 'tag': 'CAUSE_OF_DEATH'}],
#     [{'word': 'B-2', 'tag': 'MISC'}],
#     [{'word': 'US', 'tag': 'COUNTRY'}],
#     [{'word': 'US Navy', 'tag': 'ORGANIZATION'},
#      {'word': 'Tomahawk', 'tag': 'PERSON'}],
#     [{'word': 'President', 'tag': 'TITLE'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'}],
#     [{'word': 'Obama', 'tag': 'PERSON'},
#      {'word': 'Syria', 'tag': 'COUNTRY'},
#      {'word': 'Iraq', 'tag': 'COUNTRY'}],
#     [{'word': 'ISIL', 'tag': 'ORGANIZATION'},
#      {'word': 'Cook', 'tag': 'PERSON'},
#      {'word': 'ISIS', 'tag': 'ORGANIZATION'},
#      {'word': 'Islamic State', 'tag': 'ORGANIZATION'}],
#     [{'word': 'ISIL', 'tag': 'ORGANIZATION'},
#      {'word': 'attacks', 'tag': 'CAUSE_OF_DEATH'},
#      {'word': 'Libyan', 'tag': 'NATIONALITY'},
#      {'word': 'Sirte', 'tag': 'LOCATION'},
#      {'word': 'ISIL', 'tag': 'ORGANIZATION'},
#      {'word': 'Libya', 'tag': 'LOCATION'},
#      {'word': 'United States', 'tag': 'COUNTRY'}],
#     [{'word': 'Libya', 'tag': 'LOCATION'},
#      {'word': 'US', 'tag': 'COUNTRY'},
#      {'word': 'Geoff Porter', 'tag': 'PERSON'},
#      {'word': 'president', 'tag': 'TITLE'},
#      {'word': 'North Africa Risk Consulting', 'tag': 'LOCATION'}],
#     [{'word': 'Islamic State', 'tag': 'ORGANIZATION'},
#      {'word': 'Sirte', 'tag': 'LOCATION'},
#      {'word': 'Libyan', 'tag': 'NATIONALITY'}],
#     [{'word': 'Islamic', 'tag': 'IDEOLOGY'},
#      {'word': 'Sirte Basin', 'tag': 'LOCATION'},
#      {'word': 'Porter', 'tag': 'PERSON'},
#      {'word': 'CNN.A `` Targeting Islamic State', 'tag': 'ORGANIZATION'},
#      {'word': 'Sirte Basin', 'tag': 'LOCATION'},
#      {'word': 'Islamic', 'tag': 'IDEOLOGY'}],
#     [{'word': 'Porter', 'tag': 'PERSON'}],
#     [{'word': 'Libya', 'tag': 'LOCATION'}],
#     [{'word': 'Government of National Accord', 'tag': 'ORGANIZATION'}],
#     [{'word': 'GNA', 'tag': 'ORGANIZATION'}],
#     [{'word': 'GNA', 'tag': 'ORGANIZATION'}],
#     [{'word': 'ENDOFDOC', 'tag': 'ORGANIZATION'}]]}}}

# %% [markdown]
# #### Extract persons of interest from GTD data
#
# This pipe was used to extract person entities from the terror event descriptions in the GTD database.
#
# You need a StanfordCoreNLP Server running to run this cell.

# %%
INPUT_FILENAME = r'C:\Users\Simon\OneDrive - University of Exeter\__Project__\__Data__\GTD\Preprocessed Info.pkl'
OUTPUT_FILENAME = r'C:\Users\Simon\OneDrive - University of Exeter\__Project__\__Data__\GTD\GTD Persons.pkl'

ner = NER()

extract_gtd_persons_pipe = compose(
                                   curry(save_pickle)(OUTPUT_FILENAME),
                                   set,
                                   extract_persons,
                                   ner.annotate,
                                   lambda x: ' '.join(x),
                                   load_pickle,
                                   )


entities = extract_gtd_persons_pipe(INPUT_FILENAME)
